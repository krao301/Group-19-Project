# %%
pip install -U torchtext
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchtext in /usr/local/lib/python3.8/dist-packages (0.8.0)
# Collecting torchtext
#   Downloading torchtext-0.14.1-cp38-cp38-manylinux1_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 26.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchtext) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchtext) (2.25.1)
# Collecting torch==1.13.1
#   Downloading torch-1.13.1-cp38-cp38-manylinux1_x86_64.whl (887.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 MB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from torchtext) (4.64.1)
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.13.1->torchtext) (4.5.0)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 65.7 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 KB 52.0 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: wheel in /usr/local/lib/python3.8/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->torchtext) (0.38.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->torchtext) (57.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext) (4.0.0)
# Installing collected packages: nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, nvidia-cudnn-cu11, torch, torchtext
#   Attempting uninstall: torch
#     Found existing installation: torch 1.7.0
#     Uninstalling torch-1.7.0:
#       Successfully uninstalled torch-1.7.0
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.8.0
#     Uninstalling torchtext-0.8.0:
#       Successfully uninstalled torchtext-0.8.0
# Successfully installed nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 torch-1.13.1 torchtext-0.14.1

# %%
pip install -U torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (1.13.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.8/dist-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.8/dist-packages (from torch) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.8/dist-packages (from torch) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.8/dist-packages (from torch) (11.7.99)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.8/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.38.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (57.4.0)

# %%
# !pip install torch==1.7.0 torchtext==0.8.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch==1.7.0
#   Downloading torch-1.7.0-cp38-cp38-manylinux1_x86_64.whl (776.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.8/776.8 MB 2.1 MB/s eta 0:00:00
# Collecting torchtext==0.8.0
#   Downloading torchtext-0.8.0-cp38-cp38-manylinux1_x86_64.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 94.3 MB/s eta 0:00:00
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.7.0) (4.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torch==1.7.0) (1.22.4)
# Requirement already satisfied: future in /usr/local/lib/python3.8/dist-packages (from torch==1.7.0) (0.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from torchtext==0.8.0) (4.64.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchtext==0.8.0) (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.8.0) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.8.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.8.0) (1.26.14)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.8.0) (2.10)
# Installing collected packages: dataclasses, torch, torchtext
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1+cu116
#     Uninstalling torch-1.13.1+cu116:
#       Successfully uninstalled torch-1.13.1+cu116
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.14.1
#     Uninstalling torchtext-0.14.1:
#       Successfully uninstalled torchtext-0.14.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.14.1+cu116 requires torch==1.13.1, but you have torch 1.7.0 which is incompatible.
# torchaudio 0.13.1+cu116 requires torch==1.13.1, but you have torch 1.7.0 which is incompatible.
# Successfully installed dataclasses-0.6 torch-1.7.0 torchtext-0.8.0

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchtext
from torchtext.data import Field, BucketIterator,TabularDataset,Iterator
import torch.nn.functional as F

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import numpy as np

import random
import math
import time

# %%
SEED = 1011

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
tokenize = lambda x: x.split()
SRC = Field(tokenize = tokenize, 
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True, 
            batch_first = True)

TRG = Field(tokenize = tokenize, 
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True, 
            batch_first = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/torchtext/data/field.py:150: UserWarning: Field class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)

# %%
unique_fields_train_valid = [('src',SRC),('trg',TRG)]
train = TabularDataset('train.txt',format='tsv',skip_header=False,fields=unique_fields_train_valid)
valid = TabularDataset('dev.txt',format='tsv',skip_header=False,fields=unique_fields_train_valid)
unique_fields_test = [('src',SRC)]
test = TabularDataset('test.txt',format='tsv',skip_header=False,fields=unique_fields_test)
# Out:
# /usr/local/lib/python3.8/dist-packages/torchtext/data/example.py:68: UserWarning: Example class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('Example class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.', UserWarning)
# /usr/local/lib/python3.8/dist-packages/torchtext/data/example.py:78: UserWarning: Example class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('Example class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.', UserWarning)

# %%
print(len(train),len(valid),len(test))
# Out:
# 8060 942 960

# %%
SRC.build_vocab(train,valid)
TRG.build_vocab(train,valid)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
BATCH_SIZE = 32

train_iterator, valid_iterator, test_iterator = BucketIterator.splits(
    (train, valid, test), 
     batch_size = BATCH_SIZE,
     sort_within_batch=True,
     sort_key=lambda x: len(x.src),
     device = device)
# Out:
# /usr/local/lib/python3.8/dist-packages/torchtext/data/iterator.py:48: UserWarning: BucketIterator class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)

# %%
print(len(train_iterator))
print(len(valid_iterator))
print(len(test_iterator))
# Out:
# 252
# 30
# 30

# %%
class Encoder(nn.Module):
    def __init__(self, 
                 input_dim, 
                 emb_dim, 
                 hid_dim, 
                 n_layers, 
                 kernel_size, 
                 dropout, 
                 device,
                 max_length = 400):
        super().__init__()
        
        assert kernel_size % 2 == 1, "Kernel size must be odd!"
        
        self.scale = torch.sqrt(torch.FloatTensor([0.5])).to(device)
        
        self.tok_embedding = nn.Embedding(input_dim, emb_dim)
        self.pos_embedding = nn.Embedding(max_length, emb_dim)
        
        self.emb2hid = nn.Linear(emb_dim, hid_dim)
        self.hid2emb = nn.Linear(hid_dim, emb_dim)
        
        self.convs = nn.ModuleList([nn.Conv1d(in_channels = hid_dim, 
                                              out_channels = 2 * hid_dim, 
                                              kernel_size = kernel_size, 
                                              padding = (kernel_size - 1) // 2)
                                    for _ in range(n_layers)])
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, src):
        
        #src = [batch size, src len]
        
        batch_size = src.shape[0]
        src_len = src.shape[1]
        
        #create position tensor
        pos = torch.arange(0, src_len).unsqueeze(0).repeat(batch_size, 1).to(device)
        
        #pos = [0, 1, 2, 3, ..., src len - 1]
        
        #pos = [batch size, src len]
        
        #embed tokens and positions
        tok_embedded = self.tok_embedding(src)
        pos_embedded = self.pos_embedding(pos)
        
        #tok_embedded = pos_embedded = [batch size, src len, emb dim]
        
        #combine embeddings by elementwise summing
        embedded = self.dropout(tok_embedded + pos_embedded)
        
        #embedded = [batch size, src len, emb dim]
        
        #pass embedded through linear layer to convert from emb dim to hid dim
        conv_input = self.emb2hid(embedded)
        
        #conv_input = [batch size, src len, hid dim]
        
        #permute for convolutional layer
        conv_input = conv_input.permute(0, 2, 1) 
        
        #conv_input = [batch size, hid dim, src len]
        
        #begin convolutional blocks...
        
        for i, conv in enumerate(self.convs):
        
            #pass through convolutional layer
            conved = conv(self.dropout(conv_input))

            #conved = [batch size, 2 * hid dim, src len]

            #pass through GLU activation function
            conved = F.glu(conved, dim = 1)

            #conved = [batch size, hid dim, src len]
            
            #apply residual connection
            conved = (conved + conv_input) * self.scale

            #conved = [batch size, hid dim, src len]
            
            #set conv_input to conved for next loop iteration
            conv_input = conved
        
        #...end convolutional blocks
        
        #permute and convert back to emb dim
        conved = self.hid2emb(conved.permute(0, 2, 1))
        
        #conved = [batch size, src len, emb dim]
        
        #elementwise sum output (conved) and input (embedded) to be used for attention
        combined = (conved + embedded) * self.scale
        
        #combined = [batch size, src len, emb dim]
        
        #print("encoder_finished")
        
        return conved, combined

# %%
class Decoder(nn.Module):
    def __init__(self, 
                 output_dim, 
                 emb_dim, 
                 hid_dim, 
                 n_layers, 
                 kernel_size, 
                 dropout, 
                 trg_pad_idx, 
                 device,
                 max_length = 400):
        super().__init__()
        
        self.kernel_size = kernel_size
        self.trg_pad_idx = trg_pad_idx
        
        self.scale = torch.sqrt(torch.FloatTensor([0.5])).to(device)
        
        self.tok_embedding = nn.Embedding(output_dim, emb_dim)
        self.pos_embedding = nn.Embedding(max_length, emb_dim)
        
        self.emb2hid = nn.Linear(emb_dim, hid_dim)
        self.hid2emb = nn.Linear(hid_dim, emb_dim)
        
        self.attn_hid2emb = nn.Linear(hid_dim, emb_dim)
        self.attn_emb2hid = nn.Linear(emb_dim, hid_dim)
        
        self.fc_out = nn.Linear(emb_dim, output_dim)
        
        self.convs = nn.ModuleList([nn.Conv1d(in_channels = hid_dim, 
                                              out_channels = 2 * hid_dim, 
                                              kernel_size = kernel_size)
                                    for _ in range(n_layers)])
        
        self.dropout = nn.Dropout(dropout)
      
    def calculate_attention(self, embedded, conved, encoder_conved, encoder_combined):
        
        #embedded = [batch size, trg len, emb dim]
        #conved = [batch size, hid dim, trg len]
        #encoder_conved = encoder_combined = [batch size, src len, emb dim]
        
        #permute and convert back to emb dim
        conved_emb = self.attn_hid2emb(conved.permute(0, 2, 1))
        
        #conved_emb = [batch size, trg len, emb dim]
        
        combined = (conved_emb + embedded) * self.scale
        
        #combined = [batch size, trg len, emb dim]
                
        energy = torch.matmul(combined, encoder_conved.permute(0, 2, 1))
        
        #energy = [batch size, trg len, src len]
        
        attention = F.softmax(energy, dim=2)
        
        #attention = [batch size, trg len, src len]
            
        attended_encoding = torch.matmul(attention, encoder_combined)
        
        #attended_encoding = [batch size, trg len, emd dim]
        
        #convert from emb dim -> hid dim
        attended_encoding = self.attn_emb2hid(attended_encoding)
        
        #attended_encoding = [batch size, trg len, hid dim]
        
        #apply residual connection
        attended_combined = (conved + attended_encoding.permute(0, 2, 1)) * self.scale
        
        #attended_combined = [batch size, hid dim, trg len]
        
        return attention, attended_combined
        
    def forward(self, trg, encoder_conved, encoder_combined):
        
        #trg = [batch size, trg len]
        #encoder_conved = encoder_combined = [batch size, src len, emb dim]
                
        batch_size = trg.shape[0]
        trg_len = trg.shape[1]
            
        #create position tensor
        pos = torch.arange(0, trg_len).unsqueeze(0).repeat(batch_size, 1).to(device)
        
        #pos = [batch size, trg len]
        
        #embed tokens and positions
        tok_embedded = self.tok_embedding(trg)
        pos_embedded = self.pos_embedding(pos)
        
        #tok_embedded = [batch size, trg len, emb dim]
        #pos_embedded = [batch size, trg len, emb dim]
        
        #combine embeddings by elementwise summing
        embedded = self.dropout(tok_embedded + pos_embedded)
        
        #embedded = [batch size, trg len, emb dim]
        
        #pass embedded through linear layer to go through emb dim -> hid dim
        conv_input = self.emb2hid(embedded)
        
        #conv_input = [batch size, trg len, hid dim]
        
        #permute for convolutional layer
        conv_input = conv_input.permute(0, 2, 1) 
        
        #conv_input = [batch size, hid dim, trg len]
        
        batch_size = conv_input.shape[0]
        hid_dim = conv_input.shape[1]
        
        for i, conv in enumerate(self.convs):
        
            #apply dropout
            conv_input = self.dropout(conv_input)
        
            #need to pad so decoder can't "cheat"
            padding = torch.zeros(batch_size, 
                                  hid_dim, 
                                  self.kernel_size - 1).fill_(self.trg_pad_idx).to(device)
                
            padded_conv_input = torch.cat((padding, conv_input), dim = 2)
        
            #padded_conv_input = [batch size, hid dim, trg len + kernel size - 1]
        
            #pass through convolutional layer
            conved = conv(padded_conv_input)

            #conved = [batch size, 2 * hid dim, trg len]
            
            #pass through GLU activation function
            conved = F.glu(conved, dim = 1)

            #conved = [batch size, hid dim, trg len]
            
            #calculate attention
            attention, conved = self.calculate_attention(embedded, 
                                                         conved, 
                                                         encoder_conved, 
                                                         encoder_combined)
            
            #attention = [batch size, trg len, src len]
            
            #apply residual connection
            conved = (conved + conv_input) * self.scale
            
            #conved = [batch size, hid dim, trg len]
            
            #set conv_input to conved for next loop iteration
            conv_input = conved
            
        conved = self.hid2emb(conved.permute(0, 2, 1))
         
        #conved = [batch size, trg len, emb dim]
            
        output = self.fc_out(self.dropout(conved))
        
        #output = [batch size, trg len, output dim]
        
        #print("decoder_finished")
            
        return output, attention

# %%
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder):
        super().__init__()
        
        self.encoder = encoder
        self.decoder = decoder
        
    def forward(self, src, trg):
        
        #src = [batch size, src len]
        #trg = [batch size, trg len - 1] (<eos> token sliced off the end)
           
        #calculate z^u (encoder_conved) and (z^u + e) (encoder_combined)
        #encoder_conved is output from final encoder conv. block
        #encoder_combined is encoder_conved plus (elementwise) src embedding plus 
        #  positional embeddings 
        encoder_conved, encoder_combined = self.encoder(src)
            
        #encoder_conved = [batch size, src len, emb dim]
        #encoder_combined = [batch size, src len, emb dim]
        
        #calculate predictions of next words
        #output is a batch of predictions for each word in the trg sentence
        #attention a batch of attention scores across the src sentence for 
        #  each word in the trg sentence
        output, attention = self.decoder(trg, encoder_conved, encoder_combined)
        
        #output = [batch size, trg len - 1, output dim]
        #attention = [batch size, trg len - 1, src len]
        
        return output, attention

# %%
INPUT_DIM = len(SRC.vocab)
OUTPUT_DIM = len(TRG.vocab)
EMB_DIM = 256
HID_DIM = 512 # each conv. layer has 2 * hid_dim filters
ENC_LAYERS = 10 # number of conv. blocks in encoder
DEC_LAYERS = 10 # number of conv. blocks in decoder
ENC_KERNEL_SIZE = 3 # must be odd!
DEC_KERNEL_SIZE = 3 # can be even or odd
ENC_DROPOUT = 0.25
DEC_DROPOUT = 0.25
TRG_PAD_IDX = TRG.vocab.stoi[TRG.pad_token]
    
enc = Encoder(INPUT_DIM, EMB_DIM, HID_DIM, ENC_LAYERS, ENC_KERNEL_SIZE, ENC_DROPOUT, device)
dec = Decoder(OUTPUT_DIM, EMB_DIM, HID_DIM, DEC_LAYERS, DEC_KERNEL_SIZE, DEC_DROPOUT, TRG_PAD_IDX, device)

enc = enc.to(device)
dec = dec.to(device)

model = Seq2Seq(enc, dec).to(device)

# %%
def initialize_weights(m):
    if hasattr(m, 'weight') and m.weight.dim() > 1:
        nn.init.xavier_uniform_(m.weight.data)
model.apply(initialize_weights);

# %%
optimizer = torch.optim.Adam(model.parameters())

# %%
criterion = nn.CrossEntropyLoss(ignore_index = TRG_PAD_IDX)

# %%
def train(model, iterator, optimizer, criterion, clip):
    
    model.train()
    
    epoch_loss = 0
    
    for i, batch in enumerate(iterator):
        
        src = batch.src
        trg = batch.trg
        
        #print(src.shape,trg.shape)
        
        optimizer.zero_grad()
        
        output, _ = model(src, trg[:,:-1])
        
        #output = [batch size, trg len - 1, output dim]
        #trg = [batch size, trg len]
        
        output_dim = output.shape[-1]
        
        output = output.contiguous().view(-1, output_dim)
        trg = trg[:,1:].contiguous().view(-1)
        
        
        #output = [batch size * trg len - 1, output dim]
        #trg = [batch size * trg len - 1]
        
        loss = criterion(output, trg)
        
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        
        optimizer.step()
        
        epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
#train_loss = train(model, train_iterator, optimizer, criterion, 1)

# %%
def evaluate(model, iterator, criterion):
    
    model.eval()
    
    epoch_loss = 0
    
    with torch.no_grad():
    
        for i, batch in enumerate(iterator):

            src = batch.src
            trg = batch.trg

            output, _ = model(src, trg[:,:-1])
        
            #output = [batch size, trg len - 1, output dim]
            #trg = [batch size, trg len]

            output_dim = output.shape[-1]
            
            output = output.contiguous().view(-1, output_dim)
            trg = trg[:,1:].contiguous().view(-1)

            #output = [batch size * trg len - 1, output dim]
            #trg = [batch size * trg len - 1]
            
            loss = criterion(output, trg)

            epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
#' ' means CPU whereas '/device:G:0' means GPU
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
N_EPOCHS = 10
CLIP = 0.1

best_valid_loss = float('inf')

for epoch in range(N_EPOCHS):
    
    start_time = time.time()
    
    train_loss = train(model, train_iterator, optimizer, criterion, CLIP)
    valid_loss = evaluate(model, valid_iterator, criterion)
    
    end_time = time.time()
    
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'cm-model.pt')
    
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')
# Out:
# /usr/local/lib/python3.8/dist-packages/torchtext/data/batch.py:23: UserWarning: Batch class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)
# Epoch: 01 | Time: 0m 18s
# 	Train Loss: 7.412 | Train PPL: 1655.298
# 	 Val. Loss: 6.517 |  Val. PPL: 676.602
# Epoch: 02 | Time: 0m 18s
# 	Train Loss: 6.013 | Train PPL: 408.528
# 	 Val. Loss: 6.102 |  Val. PPL: 446.764
# Epoch: 03 | Time: 0m 19s
# 	Train Loss: 5.496 | Train PPL: 243.734
# 	 Val. Loss: 5.873 |  Val. PPL: 355.313
# Epoch: 04 | Time: 0m 19s
# 	Train Loss: 5.117 | Train PPL: 166.842
# 	 Val. Loss: 5.804 |  Val. PPL: 331.754
# Epoch: 05 | Time: 0m 18s
# 	Train Loss: 4.769 | Train PPL: 117.768
# 	 Val. Loss: 5.672 |  Val. PPL: 290.715
# Epoch: 06 | Time: 0m 18s
# 	Train Loss: 4.430 | Train PPL:  83.926
# 	 Val. Loss: 5.632 |  Val. PPL: 279.231
# Epoch: 07 | Time: 0m 19s
# 	Train Loss: 4.084 | Train PPL:  59.383
# 	 Val. Loss: 5.572 |  Val. PPL: 263.079
# Epoch: 08 | Time: 0m 18s
# 	Train Loss: 3.772 | Train PPL:  43.446
# 	 Val. Loss: 5.592 |  Val. PPL: 268.217
# Epoch: 09 | Time: 0m 18s
# 	Train Loss: 3.465 | Train PPL:  31.985
# 	 Val. Loss: 5.536 |  Val. PPL: 253.540
# Epoch: 10 | Time: 0m 18s
# 	Train Loss: 3.180 | Train PPL:  24.053
# 	 Val. Loss: 5.608 |  Val. PPL: 272.466

# %%
model.load_state_dict(torch.load('cm-model.pt'))

test_loss = evaluate(model, valid_iterator, criterion)

print(f'| Test Loss: {test_loss:.3f} | Test PPL: {math.exp(test_loss):7.3f} |')
# Out:
# | Test Loss: 5.536 | Test PPL: 253.540 |

# %%
def translate_sentence(sentence, src_field, trg_field, model, device, max_len = 400):

    model.eval()

    if isinstance(sentence, str):
        nlp = spacy.load('de_core_news_sm')
        tokens = [token.text.lower() for token in nlp(sentence)]
    else:
        tokens = [token.lower() for token in sentence]

    tokens = [src_field.init_token] + tokens + [src_field.eos_token]
        
    src_indexes = [src_field.vocab.stoi[token] for token in tokens]

    src_tensor = torch.LongTensor(src_indexes).unsqueeze(0).to(device)

    with torch.no_grad():
        encoder_conved, encoder_combined = model.encoder(src_tensor)

    trg_indexes = [trg_field.vocab.stoi[trg_field.init_token]]

    for i in range(max_len):

        trg_tensor = torch.LongTensor(trg_indexes).unsqueeze(0).to(device)

        with torch.no_grad():
            output, attention = model.decoder(trg_tensor, encoder_conved, encoder_combined)
        
        pred_token = output.argmax(2)[:,-1].item()
        
        trg_indexes.append(pred_token)

        if pred_token == trg_field.vocab.stoi[trg_field.eos_token]:
            break
    
    trg_tokens = [trg_field.vocab.itos[i] for i in trg_indexes]
    
    return trg_tokens[1:], attention

# %%
import pandas as pd
fin = open("test.txt",encoding='utf-8')
fout = open("predictions.txt","w+",encoding='utf-8')
count=0
for line in fin:
    count+=1
    print(count)
    line = line.replace("\n","")
    line = line.split()
    trg_sentence,attention = translate_sentence(line,SRC,TRG,model,device=device)
    print(" ".join(trg_sentence[:-1]))
    fout.write(" ".join(trg_sentence[:-1])+"\n")
# Out:
# 1
# haan, ye ek character ka tarah hein, jahan us jyaadaatar hooper kee kaarravaee ke lie dukhee nahin gaee
# 2
# han ye achha hai
# 3
# mujhe matlab hai nick wilde
# 4
# hello
# 5
# mujhe bhi or jyada find tha jo voh posrwar cheer kiya
# 6
# mujhe lagta hai wo wo ek sister kee reemek kee aavashyakata kar rahe tha
# 7
# voh tho kuch baar nahi kar sakta ho ki aap ko apne dreams ko liya jaata ho sakta hai aur wo apne dreams ko liya jaata hai aur wo ek family ko liya jaata hai aur wo ek dreams ke lie request chali deta hai aur wo ek dreams ke lie request karate ho jaata hai aur wo apne dreams ke liye bruce ho jaata hai aur wo decide kar raha hai ki wo first scene ko first karne ke liye kar kar raha
# 8
# but elsa ke liye ise dekhunga
# 9
# haan, tho mujhe pasand hein ki ye mera type ko hein
# 10
# nice!
# 11
# mujhe bhi mera movies ka pasand hein
# 12
# haan, is original ko kuch kuch nahi ho gaya aur wo great hein
# 13
# oh aur maleficent ko maleficent hein
# 14
# kya thrillers ne eres ko khun kiya tha ki mujhe lagta hai ki is part ko nahi nahi raha
# 15
# ye ache scene tho wo ek tarah ke liye bahut nahin hai, jab aap ek ek din aur aur aap aur kuch kuch pasand hai
# 16
# thik sound interesting hai ki wo use aisa nahi kar raha tha wo use baar nahi kar raha
# 17
# mujhe story pasand ki hota ki kaise wo kaise "new chahiye. kyon ki mujhe kabhi ko dekhna nahi kar sakta hu mujhe lagta hai ki ise baar ko baar ko nahi kar deta hai
# 18
# han tum definitely ise dekhunga
# 19
# hi
# 20
# mujhe bhi maleficent ko nahi diya
# 21
# kya bhi bhi bhi pasand ho?
# 22
# oh, mujhe steve carrell pasand hai
# 23
# mujhe bhi pasand hoon aap?
# 24
# hi
# 25
# tho tho tho bahut pasand hai, jo darwin ko tolerance a- hai.
# 26
# ye bahut bahut bahut hai
# 27
# is shape ke liye tho kuch pasand nahi karta hu ki wo koi movies nahi nahi sakti
# 28
# ye good
# 29
# thank
# 30
# conversation tho actually main check karna gaya
# 31
# tyooring tho dhoond underdog aur voh ana tho badiya kiya tha
# 32
# ye interesting dilchasp hai mujhe jim freeman pasand hai
# 33
# mujhe bhi! mujhe bhi us tarah ko pasand karta hai ki aapse oher ko adopt kiya
# 34
# rotten tomatoes ne 98% 98% hai
# 35
# is cast ke base se ek zyada pasand hai, lekin mujhe pasand hai aur bahut baar aur ratings aur ratings
# 36
# kya is movie ko
# 37
# abhi tho scene scenes ke scenes mei batao!
# 38
# kya tumhe pata hai jab wo sunni tha
# 39
# is rotten tomatoes ke liye bahut bahut diya aur metacritic aur metacritic
# 40
# hum tho kuch scenes nahi karta gaya
# 41
# ye tho bahut bahut bahut pasand hai jo mein world ko show kiya
# 42
# maine nahi nahi nahi ki ye kis baare mein hai?
# 43
# nahi tho mujhe lagta hai ki ye ek movies ke baare mein nahi kar sakta hu ki ye ek tarah nahin kar sakta ho? kya aap lagta hai ki kya aap lagta hai kya kya kya aap lagta hai kya kya kya aap lagta hai
# 44
# mujhe bhi dekha
# 45
# kya mein chat kar raha tha ya then
# 46
# hey
# 47
# mujhe bhi tho bahut pasand hein aur mujhe mera baare mein hai
# 48
# hello kaise ho aap?
# 49
# ye sad tha ki usne voh doonga mein end kar sakte hain
# 50
# mujhe bhi. ye ek drama film tha
# 51
# ye bahut kuch samay hai
# 52
# mujhe lagata hai ki tum movie bhi dekha
# 53
# shayad ye hai. kya ham log movie hein?
# 54
# han
# 55
# ok sorry mere paas tho ye bahut pasand hai lekin ye main story ki tarah hai.
# 56
# haan, mujhe pata hai la la la land
# 57
# kya aap nahi nahi ki us parents ko kisi ko ko played kiya
# 58
# acha tho ek character ka role ke liye bahut laga jo movie ko bhi lagta hai ki wo ek baar ko bhi bhi nahi kar raha hai
# 59
# interesting
# 60
# mujhe really lagtha hai, wonder woman ka bahut interesting hai. is movie ka bahut movies kee aavashyakata nahi hai.
# 61
# wo bahut pasand hai ki voh har type ko pasand kar raha tha
# 62
# haan
# 63
# mujhe tho adult hona nahi hota ki mujhe guess nahi gaya ki mujhe lagta hai ki main baar ki can ko pasand kar raha hu
# 64
# ye ek chejel ka guff ke baare mein hai aur wo moon ko adopt kiya tha
# 65
# kaun ka dekha?
# 66
# mujhe bhi pata hai ki agar ye us story ko recommend kar sakta hu ki toy story ki ya kahani
# 67
# mujhe bhi lagta hai is wonder woman ki is character ke liye tho movie ke liye movie ke liye ek movie ke liye movie ke liye movie ke liye
# 68
# nahi bhi kuch bahut achha hein
# 69
# movie tho is movie ko pasand kar raha hu ki wo ek baar ko aavashyakata kar rahe hai.
# 70
# acha movie ke liye bahut funny hein
# 71
# ye good bhi bahut accha hein aur koi din
# 72
# ye movie ke tarah part ke tarah ke baare mein hai jab wo decide kiya ki wo wo decide kiya
# 73
# mujhe lagta hai ki is movie ko batman ko direct kiya tha
# 74
# is part ko bhi ko bhi ke baare mein baat kar raha tha ki is movie ko bhi bhi nahi kar raha
# 75
# nahin, mujhe nahi nahi hoon
# 76
# mujhe definitely dekha hoon
# 77
# mujhe lagta hai ki log sully ko bahut nahi nahi sakta ki freeman ke liye tho bahut feel nahi kar raha
# 78
# kya aapse aap bhi bahut accha hein
# 79
# oh koi bhi agree nahi sakta ki tum is type ko nahi kar raha hu
# 80
# kya voh human ko tha jo voh ek respect tha
# 81
# main agree karta hu.
# 82
# the shape of water tho ek bada scenes tha jo elsa ke upar kee paravaah kiya hoon.
# 83
# haha
# 84
# aap ke paas pata ho jab ye abhi bhi baat kar raha ho?
# 85
# hello
# 86
# ye definitely original bhi hein
# 87
# nahi
# 88
# mujhe pasand karta hoon ki main mera parents ke saath kya nahi gaya
# 89
# great
# 90
# don eisenberg aur tom hanks aur great great
# 91
# john wick mein actually kuch nahi hein, us first ke liye
# 92
# kya is movie ke liye mein nahi gaya hain, agar ye ek baar ko reality kar rahe hain
# 93
# kya kya is movie ko dekha
# 94
# main bhi pasand hai ki ye kis baare mein hai?
# 95
# mujhe sure nahi hu ki but voh hamesha ke baare mein nahi kar sakta hu ki wo suna hai ki wo ek purpose kee kaarravaee ke lie dukhee paravaah nahi kar sakti
# 96
# han ye
# 97
# ye tho ek bahut movie hai jo tho ek samay nahi gaya
# 98
# mujhe bhi nahi nahi ki mujhe lagta hai ki mujhe movie ko pasand kar raha tha mujhe movie ko pasand kar raha tha
# 99
# mere paas
# 100
# the tho ek important robbers tha jahaan collins ko prayer karo
# 101
# ye tho ye pasand laga ki ye ek baar movie hai
# 102
# han tum definitely ise dekhunga
# 103
# jaise tho jab mia ko mia ko dekhayi gaya ki sebastian ko decide kiya ki voh use decide kiya ki voh voh dreams ko liya gaya
# 104
# mera steve suspicously million aur george aur stores ko rakha
# 105
# ye tho sense bhi nahi hota ki uska scene ko bhi bhi bhi pasand hai but wo ek baar aur ek jeevan ke liye tho aur ek jeevan ke liye tho aur ek jeevan ke liye
# 106
# mujhe bhi tho wo is movie mein bahut accha hein
# 107
# haan, voh lagta hai ki wo ek sangeet kee kaarravaee ke lie lagaaya ho gaya
# 108
# mujhe lagta hai ki is scene ke baare mein kya baat kar raha tha
# 109
# han. but jab wo kuch work kar raha tha lekin wo apne sister ko madad kar deta hai aur wo ghar ko chaahate kar raha tha
# 110
# but ham tho wo kaise ho gaya ki usne wo decide kiya aur wo ek role kaam kiya gaya hai
# 111
# aap ke baare mein kya kya kya kya kya chat karne ke baare mein kya sochte ho?
# 112
# aap?
# 113
# aur tho tho tho bhi bhi bhi accha kiya
# 114
# mera steve suspicously million aur george aur stores ko rakha
# 115
# hello!
# 116
# basically mein tho tho ko ko nahi kar deta hai aur wo ek sister ko liya gaya hai aur wo use conquer kiya
# 117
# mera pasandeeda cast hai, because wo keval solid hai because wo ek great hai.
# 118
# main meryl streep bahut acha nahin gaya but ye bahut baar
# 119
# main bhi ke memory mein nahi jata hu
# 120
# hello
# 121
# cool. tumhe sach ki mujhe mujhe pasand ho sakta hoon
# 122
# mujhe lagta hai wo abhi bhi bahut intense hai. bas
# 123
# kya is baare mein kya kya like karte hai?
# 124
# tyooring tho dhoond underdog aur voh ana tho badiya kiya tha
# 125
# kya koi koi famous actors aur koi award hain?
# 126
# haan, marvel tho bahut comedy hai but ye ek acha hai.
# 127
# is man ka man ek role play kiya jo movie mein
# 128
# koi problem nahi hai
# 129
# mujhe lagta hai wo wo ek sister ko trust kar raha tha ki ye apne sister ko kaha hai aur wo apne dreams ko nahi kar deta hai
# 130
# cool ki is baare mein kya
# 131
# ye bahut kam hai jo jyada sukhad
# 132
# khair gru ko ko help kiya ki voh ek sister ko dekhayi gaya hai aur uska samay ko aur aur aur kisi ko ko work kar raha the, aur wo ek sister ko adhik kar raha hai.
# 133
# nahin, kabhi dekha nahi nahi
# 134
# bahut bhi bhi bhi bhi hein, us uska jeevan ke liye ek adult ke liye ko lagta hai aur wo family ke liye ki movie ke liye bruce ke liye bruce ke liye bruce ke liye bruce ke liye bruce ke liye bruce ke liye bruce ke liye bruce ke liye bruce ke liye way ki
# 135
# mujhe bhi movie ke liye bahut movie hein aur voh bahut funny tha
# 136
# ye tho bahut bahut bahut pasand hai jo mein world ko show kiya
# 137
# well, rotten tomato ne maleficent ko lekar
# 138
# mujhe bhi lagta hai ki ye lagta hai ki ye lagta hai ki ye baar ko reality kar rahe kar raha tha
# 139
# kya ye happy kya
# 140
# red paas bhi bhi
# 141
# kya kya tumhe pasand hai ki aap ko ootakon kee tulana ho sakti hai?
# 142
# kya aap ke baare mein kya kya kya kya aap is movie ko kya kya ho?
# 143
# mujhe lagta hai wo wo great kiya
# 144
# perfect! hai
# 145
# gal paas pasand hai ya
# 146
# mujhe tho tho is ke baare mein kuch nahi nahi sakta ki wo aisa nahi kar sakta hu ye lagta hai ye bahut baar pasand kar raha hai.
# 147
# nahi tho mujhe lagta hai ki ye ek movies ke baare mein nahi kar sakta hu ki ye ek tarah nahin kar sakta ho? kya aap lagta hai ki kya aap lagta hai kya kya kya aap lagta hai kya kya kya aap lagta hai
# 148
# sure!
# 149
# user 2 chat karne ke liye kya kya
# 150
# oh wow tho bahut achha ho sakatee hai
# 151
# aap ke baare mein kya kya kya kya chat karne ke baare mein kya
# 152
# sometimes mujhe lagta hai mera kids ko is movie ko nahi chahiye
# 153
# mujhe bhi lagta hai ye ek carrey hein
# 154
# mujhe bhi movie ke tarah bhi bhi
# 155
# mera mouth ke upanyaas se ek guest bataye. jo wo superman ko use dee ke lie dukhee philm kee aavashyakata kee aavashyakata se aavashyakata ho sakatee hai
# 156
# ek kab jab wo ek sister ke baare mein kya aur aap ko bhi chahiye
# 157
# well, wo ek samay se find kiya aur voh ek genius fabulous hai.
# 158
# mujhe bhi bhi bhi pasand hai mujhe movie ke liye kya kya pasand ho?
# 159
# mujhe bhi ke liye ko yaad hai jo us scene ko bhi bhi laga
# 160
# ye ek comedy ke liye bahut deal thi
# 161
# main tho tho movies ka pasand hai, jo tho koi movies ko pasand karta hu ki wo kabhi movies ko pasand karta hai
# 162
# mujhe lagta hai ki the
# 163
# mujhe bhi pasand hai but ye ek baar ko pasand karta hu
# 164
# but ham tho wo kaise ho gaya ki usne wo decide kiya aur wo ek role kaam kiya gaya hai
# 165
# bye
# 166
# is man ka man ek role play kiya jo movie mein
# 167
# ah, tho ek hulk play kiya tha
# 168
# wo bahut achha hai
# 169
# wo tho bahut acha movies nahi hai, kya aap is movie ko kya kya ho?
# 170
# haan, ye bahut interesting hai because wo ek baar ko movie ke liye ki kya agar agar wo ek baar ke liye kya ho gaya
# 171
# mujhe bhi dekh sakta hu ki ye sad tha
# 172
# haan, ye tho tho us friends ko kam tha jo voh moon ko ghaayal kiya tha
# 173
# hi
# 174
# mujhe pasand hai ki ye kis baare mein hai
# 175
# hello, kaise ho aap? main nahi nahi hoon to mein is movie ko nahi kar sakte ho? kya mein is movie ko bhi chahiye
# 176
# aap kaise ho
# 177
# so good
# 178
# shayad tho bahut bahut pasand hai, mujhe lagta hai ki wo ek sister ko aavashyakata kee aavashyakata kee aavashyakata kee aavashyakata kee aavashyakata kee aavashyakata kee aavashyakata
# 179
# kya tumhe scene yaad hai kya
# 180
# movie tho kuch appealing tha
# 181
# main meryl streep bahut acha nahin gaya but ye bahut baar
# 182
# mujhe bhi sochta hoon ki mujhe bhi.
# 183
# sorry
# 184
# voh bahut achha tha
# 185
# aap bhi lagta hai
# 186
# nahin, tho tho ek character ko dekhayi gaya hai, main lagta hai ki wo ek sister kee lie ek romaanchak kee aavashyakata kar raha hai.
# 187
# ye bhi pasand hai
# 188
# is tho us memory aur uska meaning aur aur uski work ke liye
# 189
# kya ye ek samay hai
# 190
# hello
# 191
# mujhe tho ek adult bhi bhi bhi lagta hai ye ek baar movie ho rahe ho
# 192
# voh nahi nahi kyunki usne voh kuch aisa nahi kar sakta tha ki wo is movie ko nahi kar sakta
# 193
# well, mujhe nahi nahi nahi ki aap movies ke baare mein nahi lagta hai
# 194
# aap favorite part kya
# 195
# kya tho sach hai, billy goodman ek tarah hai.
# 196
# ye ek true film hai is movie mein bhi dekha hai
# 197
# 2005
# 198
# ye tho ye pasand laga ki ye ek baar movie hai
# 199
# haan film tho bhi bhi is movie ko jarur chahiye
# 200
# aap tho bhi bhi bhi laga
# 201
# mujhe bhi bhi bhi
# 202
# badiya. kya tumhe actor movies movies hai
# 203
# mujhe see, tho history ho sakti hai? kya kaise kya kya chat karne ke baare mein kya ho?
# 204
# oh yeah! kya aapse year
# 205
# main bhi agree kar sakta hu
# 206
# ye tho kuch kuch nahi laga mujhe lagta hai ki ye ek majedaar ke liye kya nahi kar raha
# 207
# mujhe lagta hai ki ye bahut background tha jab mujhe lagta hai ki mujhe baar bhi nahi sakta hu mujhe lagta hai ki mujhe baar bhi nahi sakta hu
# 208
# mujhe movie pasand hai ki ye ek baare mein kya kya suna ho?
# 209
# mujhe wonder woman ki wonder woman ki movie ki first movie ko pasand hai. mujhe movie pasand hai
# 210
# to is movie mein ek ek kahaanee hai jo lagata hai ki ye achha hai.
# 211
# kuch kuch bhi bhi hein, jab wo us baar ko ko kaha ho gaya ki jab wo apne friends ko kuch nahi nahi gaya
# 212
# umm.. koi sakal drying nahi gaya
# 213
# hi!
# 214
# sorry
# 215
# wo ek best pasand hai lekin ye suna hai but ye nahi pasand hai
# 216
# ye tho mujhe dekhna chahiye ki kaise kaise chahti ho
# 217
# mujhe tho ek game ka tarah pasand hai jo ye ek day!
# 218
# kya ye ise awards ho gaya
# 219
# thank
# 220
# mujhe bhi movie ke baare mein hai jo ye movie ke baare mein hai
# 221
# robert downey jr iron iron downey jr ka guest guest appearance
# 222
# haan, mujhe pata hai la la la land
# 223
# yeah!
# 224
# mujhe pta hai ye ye ek genius thi
# 225
# thik ho paloonga
# 226
# aap bhi lagta hai ki ye sad hai ya happy ya ya happy ya ya kya ya happy ya ya kya ?
# 227
# name uski try thi?
# 228
# kya tho ek character ke baare mein
# 229
# mujhe bhi bhi bhi bhi kuch pasand hoon to main kuchh baar ko chaahie?
# 230
# ye tho true bahut pasand hai
# 231
# hello! kaise kya aap aap nahi ho? kya tum movie dekhi hai?
# 232
# haan, ye ek ek bahut robot tha
# 233
# yeah!
# 234
# movie tho acha hi hai, - mera time ke liye tho bahut movie hai, lekin ye ek movie ke liye tho kya hai.
# 235
# oh mera pass pasand hai aur koi koi any philmen hai
# 236
# kya tumhe yaad hai ki wo apne bachche ke liye
# 237
# rotten paas eske dhanyawad
# 238
# ye mool roop se idris taink ke lie heh
# 239
# mujhe pasand hai ki ye kis baare mein hai
# 240
# aur voh previously power ko le gaya ki wo wo apni sister mein le gaya tha aur wo unsucessful hai
# 241
# hi
# 242
# shawn dicaprio bhi tho mera award nahi :)
# 243
# ohh
# 244
# mujhe nahi nahi dekhi
# 245
# ye bhi bhi final howard ko used laga
# 246
# mujhe bhi aisa nahi nahi hota ki wo ek character ke baare mein kya kar raha hain?
# 247
# kya aap ko dunkirk ko dekha ho?
# 248
# ye tho really bahut hard hein, jo voh ek baar ko feel kar raha tha aur wo ek baar ko hoga
# 249
# aap ka movie ke baare mein kya sochate ho?
# 250
# aur haan, wo bhi ko ko ko ko ko le deta hai ki wo ek family ke liye ko nahi kar raha tha aur wo ek baar ko work ke liye kaam kiya hai
# 251
# mujhe bhi lagta hai ki is kids ko bahut funny laga
# 252
# robert downey jr tho ek walken kya kya amazing kaun hain?
# 253
# mujhe lagta hai ki cast hai
# 254
# mujhe bhi bhi bhi bhi kuch pasand hoon to main kuchh baar ko chaahie?
# 255
# haan, mujhe bhi bhi accha laga jo gatsby ko accha kar diya
# 256
# stan ka ka jack game hai
# 257
# haan, aap bhi bhi
# 258
# voh nahi nahi kyunki usne voh kuch aisa nahi kar sakta tha ki wo is movie ko nahi kar sakta
# 259
# hello! kaise kya aap aap nahi ho? kya tum movie dekhi hai?
# 260
# kaun ka dekha?
# 261
# mujhe bhi pasand hai ki ye bahut kid ki movie pasand hai
# 262
# hello
# 263
# wo pasand hai
# 264
# jab voh apni parents ko achieve karne ke liye
# 265
# hello!
# 266
# movie ka movies ko pasand karte ho?
# 267
# mujhe tho abhi bhi bhi bahut laga lekin mujhe bhi bhi nahi hein, lekin mujhe lagta hai ki ye ek baar ko pasand nahi karta.
# 268
# aur first nahi nahi
# 269
# mujhe bhi pasand hai aur kuch pay nahi gaya lekin kuch baar
# 270
# mujhe lagta hai ki aapako kuchh pasand karate hai, agar tum ise ootakon kee kaarravaee kee aavashyakata thee. aap lagta hai
# 271
# aap tho is film ko pasand hein, yeh rotten tomatoes kee fifty rating mile
# 272
# oh haan, agar wo ek kid ko pasand karta hu ki ye ek baar ko pasand karta hai.
# 273
# kya ka kuch pasand hai
# 274
# yah tho ek ek movie kee kuki mera opinion
# 275
# thank
# 276
# koi reviews reviews hai?
# 277
# bye
# 278
# aap bhi lagta hai
# 279
# ye tho kuch kuch nahi laga mujhe lagta hai ki ye ek majedaar ke liye kya nahi kar raha
# 280
# haan, director ka director kaun hai bye
# 281
# han ye ek ek animated philm hai
# 282
# ye definitely bhi lagta hai ki ye movie ke baare mein kya lagta hai ki movie ke baare mein kya sochte ho? kya tumhe lagta hai ki movie ke baare mein kya sochte ho?
# 283
# mujhe agree, is scenes ko pasand hai, jo ek deutsches kurl story ke lie janak philm kee aavashyakata kee aavashyakata kee aavashyakata kee aavashyakata kee aavashyakata kee aavashyakata kee aavashyakata se aavashyakata hein
# 284
# han
# 285
# haan! tho tho bahut time hein, jo ye ek prem philm kee aavashyakata kee aavashyakata kee aavashyakata kee aavashyakata kee aavashyakata hai. kya ye ek solid hai.
# 286
# mujhe bhi movie ke tarah bhi bhi
# 287
# mujhe ye pasand hai ki ye us type ko pasand hein, aur mujhe bhi ke baare mein bhi bhi nahi hoon
# 288
# ye setting films hai
# 289
# hello, kaise ho aap?
# 290
# aur ye action bahut achha hai
# 291
# mujhe bhi lagata hai ki vah din
# 292
# hello!
# 293
# mujhe assume karta hu ki judy ke paas interaction ho jaata hai
# 294
# hello!
# 295
# lol mujhe matlab hai usne wo apne sister ko shaamil kar sakte tha
# 296
# conversation ke liye kya nahi karta hu ye nahi nahi karta
# 297
# sahi
# 298
# kaise
# 299
# kya kya emma jaga ke liye magic mein:)
# 300
# mujhe lagta hai wo wo ek sister kee reemek kee aavashyakata kar rahe tha
# 301
# kya wo kuch hi hein
# 302
# mujhe bhi alone bhi pasand hai jab ye dekha hai
# 303
# main bhi tho bahut low hein
# 304
# mujhe nahi nahi hai ki
# 305
# kya main main debt mein hein, aur us girlfriend ko kuch chaahate ho gaya hai aur wo ek purpose aur ya kahaanee aur refresh kar raha hai
# 306
# kya aap ke cast ke baare mein kya kya kya ? ya end ke sath
# 307
# of box ke liye
# 308
# aur fir ek samay actress hai
# 309
# ye bhi bhi bhi dekha hoon but ye bahut acha hein
# 310
# ye mujhe pasand hai ki ye ek part ke lie bhi bhi pasand hai. tumhe lagta hai ki ye baar ko baar watch karna kar sakti hai.
# 311
# of bhi
# 312
# kya tumhe lagata hai ki is genre ko bhi sochate ho?
# 313
# amazing ka billionaire hai
# 314
# movie ka superhero superhero ka mile jo leonardo dicaprio ka movies ke baare mein hai, jo marvel bullock ke baare mein kya sochte ho?
# 315
# han main nahi
# 316
# haan, aap nahi nahi ki aap kya kya the?
# 317
# mujhe bhi nahi nahi hoon
# 318
# yah steve carrell hai, kya main suna hai ki ye almighty ko lagata hai ki ye almighty ko dekha hai
# 319
# mujhe mera favorite ke baare mein soch raha hu ki agar jab kuch nahi nahi gaya jab agar main nahi nahi gaya
# 320
# mujhe bhi sochta hoon ki mujhe bhi.
# 321
# movie tho is movie ko pasand kar raha hu ki wo ek baar ko aavashyakata kar rahe hai.
# 322
# haan, voh bahut good hai.
# 323
# mein tho kaha ki jahan wo direct kiya hai
# 324
# ye sad hai
# 325
# voh tho batman ko attack karne ke liye bruce ko apane sister ko lekar ko le deta hai aur wo ek sister ko liya gaya hai
# 326
# mujhe bhi main pata hoon ki mujhe ise check karna chahiye
# 327
# us aadmi ko eres ko saphalataapoorvak pretentious aamantrit kar rahe the, jab wo kuch baar ke baare mein kya bata raha ho,
# 328
# mein kya
# 329
# humanity ka kuch samay ke liye bahut nahin gaya
# 330
# is tho tho bahut accha hein jo ye ise jackman hein
# 331
# unke movie ka lady mod hai jo ki
# 332
# ye ek voice kee thrill hai, because aap ko pasand karta hain, because aap ko baar ko pasand kar raha hai. because tum lagta hai ki
# 333
# aap kya kya kya tumne is movie ko hai?
# 334
# kya tumhe lagata hai ki ye ek sad hai ki movie ke liye kya hein?
# 335
# khair ye tho tho jab jab jab jab tho us character ko ek achchha hai. to ye ek ek part ke saath ek philm ke liye ek philm ke saath ek philm ke saath se hai.
# 336
# wow, maleficent ko losef ko stefan ko used ko nahi gaya aur usey baar ko off karna kar raha tha.
# 337
# haan film tho bhi bhi is movie ko jarur chahiye
# 338
# so yar.. ki wo sleeping beauty ki hai
# 339
# aap ke baare mein kya kya kya kya chat karne ke baare mein kya
# 340
# emma stone ka ryan gosling ka review bhi hein
# 341
# hi
# 342
# kya partner*
# 343
# kya main character hai jo ek character kaun hai
# 344
# main bhi pasand hai ki ye kis baare mein hai?
# 345
# hello? to koi koi nahi nahi tha
# 346
# nope, bhee, tho ek great actor hai jo pramukh character play kiya
# 347
# haan, mera mera movie ke saath movie hai
# 348
# ye tho uske liye ko dekhunga
# 349
# ye ek voice kee thrill hai, because aap ko pasand karta hain, because aap ko baar ko pasand kar raha hai. because tum lagta hai ki
# 350
# aur first nahi nahi
# 351
# main bhi bahut acha feel karta hu
# 352
# hi is movie ka movie ki movie hai
# 353
# robert downey jr tho ek walken kya kya amazing kaun hain?
# 354
# mujhe lagta hai ki tum ise doonga ki voh har bachche ko kaarravaee nahi kar raha tha.
# 355
# aap aap ka matalab hai kya kya kya kya kya kya ? kya kya kya ?
# 356
# is is tarah ko hein, jo lagta hai ki wo apne liye ko nahi kar sakta hu ki wo ek baar ko liya kar raha hai.
# 357
# mujhe maantha hoon. mujhe lagta hai ki mujhe bhi ko nahi nahi nahi but mujhe bhi nahi nahi sakta
# 358
# stan ka ka jack game hai
# 359
# mujhe bhi dekh sakta hu agar mera paas doonga aur tum use pasand ho sakta
# 360
# ve ek drephas kee 2d kee adhik pasand karata hu
# 361
# thank
# 362
# khair ve ek samay ke liye look kar raha the, aur wo apne dreams ke liye hone ke liye criticize kar raha tha aur wo apne dreams ke liye hone ke liye kar raha hai aur wo ek dreams ke liye hone ke liye
# 363
# movie robert downey jr ne robert downey dc director hein
# 364
# awesome mein ke liye haha
# 365
# ya movie tho ek movie ke baare mein kya kya hain?
# 366
# bahut bhi hissa thee, yeh ek tarah kee kaarravaee ko aavashyakata pasand kiya hai
# 367
# then ve apane samay ko find kar raha tha aur kuch conversation ke liye
# 368
# well, mujhe is movie ko dekh sakta hu
# 369
# mujhe toh try kiya tha ki ye ek type ke baare mein hai
# 370
# haan, ve kaha ho gaya ki veh computer end ko badguys
# 371
# well, ye bhi ka part ka part jo ek hero ka tarah kee romaanchak hai jo ek hero ka tarah kee romaanchak ki experiences ke liye
# 372
# kya tumne dekha
# 373
# ye tho mera lindsay time se pasand hai, jab wo bhi bhi pasand hai jab wo ye bhi bhi pasand hai.
# 374
# jim carrey ko nahi hein, aur uska girlfriend ko ko database ko relate kar raha the, aur wo ek sister ko jaatee hai aur wo ek sister ko boarding karne ke liye bruce ke liye bruce ke liye bruce ko kar deta hai
# 375
# hey
# 376
# movie ka story ki hai
# 377
# kya voh kuch samay ho gaya
# 378
# haan, us characters ka role ka rings tha jo us gudamain-hil ko saken.
# 379
# kya wo aur aur aur aur aur aur aur aur aur slip ko work kiya
# 380
# bahut bahut achha hai
# 381
# ye action stories pasand hai but
# 382
# wo ek best pasand hai lekin ye suna hai but ye nahi pasand hai
# 383
# haan, but tho ek pasand hai, aur movie ka pasand hein
# 384
# mujhe believe laga ki yah believe nahi hota ki ye sach ko pasand karta hu
# 385
# john legend ka baat role hai
# 386
# to is ek power find diya.
# 387
# to ye ek face hai, lekin mujhe lagata hai ki ye lagata hai ki wo life ko aisa karna chahiye
# 388
# ya movie tho ek movie ke baare mein kya kya hain?
# 389
# ye ek chejel dvaara craig butler,
# 390
# wow mujhe lagta hai
# 391
# nirasat ke saath wo decide kiya ki wo apne guru
# 392
# kya is movie ko
# 393
# hi
# 394
# kya aap ko shape of water ko pasand ho?
# 395
# mujhe nahi nahi hu ki main movie ke baare mein kya
# 396
# nahi tho uska samay ko hone ke liye hone ke liye hone ke liye hone ke liye hone ke liye hone ke liye hone ke liye kar raha hai.
# 397
# mujhe lagta hai ki ye bhi nahi nahi sakta ki ye movie ko pasand kar raha ho?
# 398
# haan ye cool hai
# 399
# conversation ke liye thanks
# 400
# sach ke liye thanks ki end ko end ke liye
# 401
# is movie ka story ki story ki tarah kiya gaya ki wo ek work kee lie way ko liya jaata hai aur wo work karne ke liye kaam kar raha tha aur wo ek dreams ke liye kaam kar raha hai.
# 402
# oh, mujhe steve carrell pasand hai
# 403
# aur bhi tho bahut logical laga jab wo ek paartee hai
# 404
# movie tho really bahut achha hein
# 405
# movie tho kafi interesting hai. jo ekshan thrillers ko aaya
# 406
# mujhe tho aisa hona kar sakta hu mujhe movie dekh sakta hu
# 407
# mujhe tho us movie ko end nahi nahi sakti
# 408
# ye bhi bullock ko nahi nahi sakta ki mujhe ise aisa pasand kar sakta hu
# 409
# kya emma stone aur ryan gosling ko acha nahi hein
# 410
# ah ye lagta hai ki mujhe ek character kee baare mein suna hai ki ye pramukh godel mein kisane roles mein hein?
# 411
# kya maantha hoon aur main keira knightly kee pasand nahi karta
# 412
# mujhe tho bahut acha kaam kiya ki wo ek role ko feel kar rahe tha jab mein apne paas ko reality ke liye
# 413
# ye tho ek pretty thriller hai, jo darwin ke liye magic kee prem kahaanee kee prem kahaanee kee lie kahaanee ke liye kya hai.
# 414
# hello!
# 415
# mujhe is movie ko suna hai lekin ye is movie ko dekh raha hoon
# 416
# movie ka superhero superhero ka mile jo leonardo dicaprio ka movies ke baare mein hai, jo marvel bullock ke baare mein kya sochte ho?
# 417
# ye bahut funny hai
# 418
# kya
# 419
# maleficent milli hai ek help huva ki uska samay ko afford kiya jo bahut funny feel gaya hai
# 420
# kaafi good score hai
# 421
# ye good
# 422
# mujhe is movie ko movie ki tarah kiya hain, kya
# 423
# ohh sorry
# 424
# kya mujhe bhi bhi pasand hai jo government ko government ko government
# 425
# user 2 chat karne ke liye kya kya
# 426
# vaise wolverine apne shared army ko pasand karta hu
# 427
# kaun mein?
# 428
# ye lagta hai ki wo yaad hai ki is movie ko kuch lagta hai ki is movie ko kuch lagta hai ki is movie ko bhi lagta hai
# 429
# haan, tho ek din ko find karta hu aur ye chid tha
# 430
# is ek favorite character hai is movie mein
# 431
# ab mujhe yaad hai ki mujhe superhero movies mein bhi bhi bhi
# 432
# thanks bye
# 433
# wo crazy hein ki aap nahi nahi sakta agar tum nahi nahi sakta
# 434
# haan, mujhe really pasand hein ki ye ek ek pasand hein
# 435
# ye tho bhi movie nahi hein, agar aap lagta hai ki wo ek friend kee kaarravaee kee lie santoshajanak hai. agar aap lagta hai ki wo ek sister kee aavashyakata kee aavashyakata kee aavashyakata kee aavashyakata ho sakatee hai
# 436
# khair ye really really acha hai, kya aap mein batana hain? kya tum batao.
# 437
# is ek fox ke liye jab jo ek fox ko dekhayi gaya aur wo ek sister se prem kahaanee se prem way ko pasand kar raha hai aur wo ek sister se prem kahaanee se pasand hai.
# 438
# kya kya kya kya kya kab kab thi?
# 439
# kevin tho us baar ko nahi hein, mujhe lagta hai ki wo ek din ke baare mein hai, lekin ye ek character ke baare mein hai.
# 440
# wo wo role play karte hai?
# 441
# mere paas agree karna
# 442
# the tho ek important robbers tha jahaan collins ko prayer karo
# 443
# mujhe assume karta hu ki judy ke paas interaction ho jaata hai
# 444
# mujhe matlab nahi hai
# 445
# aap ke baare mein kya kya kya kya kya chat karne ke baare mein kya sochte ho?
# 446
# sach really interesting nahi nahi nahi ye ye pasand nahi hai
# 447
# to us guy ko aur tamam find tha aur us page ko ya page ke baare mein kya kar raha tha ya wo page ke liye kya ya naatak.
# 448
# ye ek best movie hai
# 449
# haan, ye tho tho us friends ko kam tha jo voh moon ko ghaayal kiya tha
# 450
# ye ek ek memory ki pasand hai
# 451
# ye tho mein ke liye ko se hein, jo tho is movie ko se nahi kar raha tha ki ye ek baar ko pasand kar raha hai
# 452
# mujhe pasand karta hoon ki main mera parents ke saath kya nahi gaya
# 453
# ye tho aur khud ko hein, jo ek ganit ko pasand kar raha tha aur wo ek baar ko adhik bana jaata hai
# 454
# mujhe apne 15 ko se mis aur voh jyaadaatar bachche se gaya?
# 455
# kya nahi nahi nahi nahi
# 456
# ye tho tho tho tho bahut character ke liye tho kuch lagta hai ki wo ek baar ko movie ke liye way ke liye way ke liye way ke liye way ke liye way mein nahi kar raha
# 457
# information ko baat kiya
# 458
# main movie ka role play kiya hai
# 459
# haan, aur ek closing man se find kiya
# 460
# kya sorry ki iron opinion mera end par
# 461
# cool! mujhe tho to to to dekh sakta hu ki ye check karunga
# 462
# mujhe tho really scores nahi karega so mujhe lagta hai ki is review ko nahi nahi sakta
# 463
# us log ko naav ko saphalataapoorvak pretentious prashansa kee gaee else elsa ko kisane chaiye
# 464
# mujhe bhi pasand hai ki yeh ek scene ko pasand karta hai ki wo ek advanced story kee tarah kiya
# 465
# freeman rotten tomatoes par metacritic score diya tha but ye movie ke liye
# 466
# action?
# 467
# ye kuch scene ke liye kuch scene
# 468
# the ke yaatra ko
# 469
# to tumhe lagata hai ki aapako is movie ko recommend karoge
# 470
# us aadmi ko eres ko saphalataapoorvak pretentious aamantrit kar rahe the, jab wo kuch baar ke baare mein kya bata raha ho,
# 471
# jaise tho jab mia ko mia ko dekhayi gaya ki sebastian ko decide kiya ki voh use decide kiya ki voh voh dreams ko liya gaya
# 472
# haan, ye tho tho kuch time nahi mila,
# 473
# mujhe suna hai ki ye kab release hai
# 474
# oh sach wo ek achchha character hai
# 475
# tumhe movie ke baare mein kya sochate ho?
# 476
# uska paas try kar raha tha jab wo ek sister se world.
# 477
# main bhi sehmat hoon
# 478
# acha tho bhi kaise kiya ki usne har dreams ko kaam kiya hai.
# 479
# ye good
# 480
# mere paas bhi mera robert downey kee feel hein, wonder woman ko wonder woman ko pasand karta hu.
# 481
# haan, ye first samay ke liye thank first ke liye ke liye ke liye
# 482
# mujhe tho aur end ke liye hone ke lie kar sakte tha
# 483
# emma stone ka ryan gosling ka review bhi hein
# 484
# aap kya kya kya
# 485
# haan, aur tho tho is movie ko pasand hein, lekin ye lagta hai ki ye kabhi pasand nahi kar sakta hoon mujhe lagata hai ki ye ek baar pasand hai lekin mujhe lagta hai ki ye baar pasand nahi sakta hai.
# 486
# kya aap ke baare mein kya kya kya kya aap is movie ko kya kya ho?
# 487
# mujhe setting stories ka naam pasand hai
# 488
# han
# 489
# khair main nahi hu ki wo ek family ke liye ko nahi kar raha tha ki wo ek baar ko le deta hai ki wo ek baar ko liya
# 490
# kya voh kuch samay ho gaya
# 491
# the tho ek kahate hai ki iron man ko bahut diya hein
# 492
# ah mean girls tho funny movie hai kya tumne dekha
# 493
# ye tho acha hi acha hi jo movie ko better hi diya
# 494
# wo tho bhi underdog aur voh ek solid ka ekshan kaam kiya hai
# 495
# mujhe tho aur jaroor hein, aur voh jyaadaatar purpose ko nahi kar sakti hu
# 496
# nahi bhi pasand hai
# 497
# aap ke baare mein kya sochte ho?
# 498
# wo hai
# 499
# then ve apane samay ko find kar raha tha aur kuch conversation ke liye
# 500
# to, tho tumhe girls ko wonder deta hai ki ye ek baar ko pasand karta hai
# 501
# haan, main bahut sure hai jab mein shayad
# 502
# cool. kya is film ko is movie ko dekh sakte ho? kya tum khayal ho ki kya tumhe khayal hai ki kya tumhe baar ke baare mein kya sochte ho?
# 503
# kya aap ko dunkirk ko dekha ho?
# 504
# mujhe bhi accha krke accha laga
# 505
# bahut ache hi acha laga jo kaise nahi pasand sakta
# 506
# haan, ye ek character ka tarah hein, jahan us jyaadaatar hooper kee kaarravaee ke lie dukhee nahin gaee
# 507
# to ye ek face hai, lekin mujhe lagata hai ki ye lagata hai ki wo life ko aisa karna chahiye
# 508
# lol, yar.. tumhe tho us behen ke baare mein kya bhool jaata hu
# 509
# koi bhi part ka part
# 510
# oh wow! yeh ek great movie hai
# 511
# kya tumhe rulane wali movies pasand ho?
# 512
# wo tho uska role ko find kiya
# 513
# han wo kya
# 514
# to mujhe lagata hai ki gru ko bahut intense hai.
# 515
# kya yar.. ki us done
# 516
# agar ham tho ek kid ke baare mein baat kar raha ho ki ye historical gadot ke baare mein baat kar raha ho?
# 517
# mujhe bhi mera movies ka pasand hein
# 518
# is shape ke liye tho kuch pasand nahi karta hu ki wo koi movies nahi nahi sakti
# 519
# tho bahut bahut bashing nahi hota ki movie ko ek saare family kee tarah feel karta hai
# 520
# have
# 521
# oops main tho tho surprised hein, kyon ki voh ek scene ko pasand karta hu
# 522
# mujhe lagta hai ki ye movie nahi kar sakta hu
# 523
# john legend ka baat role hai
# 524
# kya voh bhi bhi guy tha ki voh apne kids ko work kiya tha
# 525
# haan, mujhe manta hu. kya aap ko yaad nahi karta hu mujhe scene ke liye bhi nahi nahi sakti
# 526
# kya tho tho ek character ke baare mein hai
# 527
# yeah! yar.. tho ek movie ke liye par mein:)
# 528
# mujhe bhi nahi nahi hota ki mujhe lagtha hai ki ab kabhi bhi nahi nahi sakta ki ye lagtha hai ki mujhe lagta hai ki ye bhi bhi bhi nahi nahi sakta
# 529
# rotten tomatoes ne rotten tomato par kya hey
# 530
# wo image gold" bolke ko pasand karta hoon. mujhe ke baare mein kya nahi kar sakta hu agar main first ke baare mein nahi kar sakta
# 531
# mujhe tho tho tho hein, jo tho us movie ke baare mein suna hai ki ye movie ke baare mein kya suna hai.
# 532
# mein kya
# 533
# aap ke baare mein kya sochte ho?
# 534
# tumhe movie pasand karta ho?
# 535
# of
# 536
# kya tumhe lagta hai ki is actors ka movie kya hain?
# 537
# mujhe lagta hai ki ek great movie hai. kya tumhe lagata hai ki kya is movie ko kya sochate ho?
# 538
# hello!
# 539
# yaha
# 540
# mujhe bhi lagta hai ki ye lagta hai ki ye lagta hai ki ye baar ko reality kar rahe kar raha tha
# 541
# red paas bhi bhi
# 542
# oops tho mera bhi bhi ki jab jab jab jab jab us kid ko hein, mujhe lagta hai
# 543
# well, ye ek ek philm film hai
# 544
# mujhe ye pasand hai ki ye kaapa ko adopt kiya
# 545
# ye interesting dilchasp hai mujhe jim freeman pasand hai
# 546
# aap ke baare mein kya sochte ho?
# 547
# haan, ye ek true hai, jo ek true story ke liye bahut philm hai. lekin ye ek great hai.
# 548
# is is tarah ko hein, jo lagta hai ki wo apne liye ko nahi kar sakta hu ki wo ek baar ko liya kar raha hai.
# 549
# haan, ve kaha ho gaya ki veh computer end ko badguys
# 550
# great ke baare mein kya kya ho?
# 551
# tho mujhe vishvaas nahi karta hoon
# 552
# haan, mujhe really pasand hein ki ye ek ek pasand hein
# 553
# aap kya kya kya
# 554
# mujhe monsters university ko pasand karta hu ki is monsters side ko nahi kar raha hu
# 555
# mujhe lagta hai ki tum apne paas ko bata sakte ho?
# 556
# koi movie ke baare mein
# 557
# story story story ke baare mein ek jeevanee hai, jo ek jeevan ka play karane ke liye ek philm kee aavashyakata ke liye kee philm ka aavashyakata play kiya
# 558
# hey
# 559
# tumhe gal gadot kee pixar lagata hai ki wonder woman ka kya sochate ho?
# 560
# mujhe bhi ko ko ko nahi nahi hein, mujhe lagta hai ki is genre ko bhi pasand karta hu.
# 561
# haan, ye bhi ko ko play kiya jo ek role ka role kaam kiya hein
# 562
# haan, director ka director kaun hai bye
# 563
# koi movie ke baare mein
# 564
# aur first bhi bhi
# 565
# voh tho ek bahut pasand hein jo tho ab bahut funny hai.
# 566
# yah steve carrell hai, kya main suna hai ki ye almighty ko lagata hai ki ye almighty ko dekha hai
# 567
# aur cinema a+ hai
# 568
# han
# 569
# mujhe nahi nahi hai ki
# 570
# mujhe tho tho is ke baare mein kuch nahi nahi sakta ki wo aisa nahi kar sakta hu ye lagta hai ye bahut baar pasand kar raha hai.
# 571
# well, mujhe lagata hai ki ye ek happy movie hai
# 572
# kya kya
# 573
# kya tho yeh bhi bhi lega usne bahut comical ho
# 574
# han - sandra bullock ki us rag kid aur aur freeman ko pasand hai.
# 575
# kya ye lagata hai ki ye ek dion se hai?
# 576
# haan, ye tho tho is movie ko kaise kar deta hai is movie ko kya sochte ho?
# 577
# freeman rotten tomatoes par metacritic score diya tha but ye movie ke liye
# 578
# maleficent maleficent ne maleficent thi!
# 579
# thank
# 580
# kya partner*
# 581
# ye bahut achha hai
# 582
# mujhe tho kya kya kya kya aap is movie ko kya kya ho?
# 583
# oh yeah! ye tho tho bahut pasand hein, mujhe lagta hai ki ye pasand hai
# 584
# vegas mein mein main aur?
# 585
# mujhe bhi bhi bhi bhi nahi gaya
# 586
# kya
# 587
# oh haan, tho ek ek genius find gaya hai
# 588
# haan, mujhe bhi mera tomatoes ke baare mein bhool gaya hoon main lagta hai ki main ek baar movie ke liye aap nahi kar raha hoon
# 589
# aap scene ke liye yaad hai aur kya kya pasand hai
# 590
# badia tho yah ek tyooring jr jo ek ruffalo ken romaanchak aur tom hardy ko variety ki wow
# 591
# oh haan, tho ek ek genius find gaya hai
# 592
# is avengers tho bahut achha hein
# 593
# mujhe bhi, classic ek ek favorite hai
# 594
# :)
# 595
# main agree karta hu.
# 596
# mujhe bhi bhi bhi bhi hi movie ke liye ek movie ke baare mein ek ek romaanchak hai jab wo ek duty naatak hai.
# 597
# ye bhi ek memory ko ek aunt kee marna kaam kiya hai
# 598
# nahi bhi first nahi nahi
# 599
# kya tumne dekha
# 600
# aap ne british army ko pasand ho sakti
# 601
# haan, mujhe agree hu - ki tho sach ke baare mein pta hai ki wo lagta hai ki wo apne baare mein kaha hai aur wo lagta hai ki wo apne dreams ko kaha hai aur wo apne baare mein kaha hai
# 602
# aap ke baare mein kya sochte ho?
# 603
# voh surprise se bahut jyada diya
# 604
# uska paas try kar raha tha jab wo ek sister se world.
# 605
# wow ye lagta hai ki vah attractive.
# 606
# agar ye pretty interesting movie hai is point ko
# 607
# don eisenberg tho voice of voice tha
# 608
# main sure nahi nahi ki ye ek baar ko feel kar deta hai ki wo ek baar ko feel kar deta hai ki wo ek baar ko leke ko nahi kar deta hai
# 609
# abhi tho yeh bhi pasand hai jab wo ye baar kee kaarravaee ke lie majedaar ho sakatee hai
# 610
# indeed.
# 611
# movie ka name kya
# 612
# jim carrey ka ache choice tha jo movie ke liye
# 613
# aap kis baare mein kya kya kya chat karne ke baare mein kya sochte ho?
# 614
# aap is movie ke baare mein kya sochte ho?
# 615
# is movie mein bahut achchha hai. jab voh ek minute handle kar gaya
# 616
# is avengers tho bahut achha hein
# 617
# ye mera baar ko dekha hai
# 618
# mujhe tho koi kid nahi hai, but mujhe bhi movies ke fan nahi hoon
# 619
# jab tho tho supernatural hanks kee thrill tha?
# 620
# movie tho kuch appealing tha
# 621
# kya
# 622
# kya tumne lagta hai ye ek achha kee aavashyakata hoga?
# 623
# mujhe bhi lagta hai mere paas bhi bhi
# 624
# mujhe bhi bahut pasand hein
# 625
# thank aap ko conversation kar rahe ho?
# 626
# ye reviews reviews hai
# 627
# aap kis baare mein kya kya kya chat karne ke baare mein kya sochte ho?
# 628
# main sach mein main kalpana kar raha hu ki ye is movie ko pasand karta hu
# 629
# thik ho paloonga
# 630
# aap tho uske baare mein kuch nahi janta hu
# 631
# kya is side ko end ko end ke liye
# 632
# mujhe matlab hai mujhe bhi pasand hai ki wo hamesha ko nahi gaya gaya ki wo wo bhi to lol
# 633
# kya
# 634
# to tumhe lagata hai ki aapako is movie ko recommend karoge
# 635
# ye to to omg
# 636
# hello, kaise ho aap? main nahi nahi hoon to mein is movie ko nahi kar sakte ho? kya mein is movie ko bhi chahiye
# 637
# nahin, mujhe tho us part ke baare mein
# 638
# mujhe agree, tho yeh pasand hein ki ye ek baar ko aanand diya
# 639
# wo tho stefan ko puppy ko chatha tha jo uska ghar ko saken.
# 640
# aap ne british army ko pasand ho sakti
# 641
# mujhe bhi ke baare mein kuch nahi nahi hoon
# 642
# movie bhi dekha
# 643
# ye naav ko evil tha lekin jyada limousine
# 644
# kya voh uske liye ko liya gaya
# 645
# mujhe bhi
# 646
# name uski try thi?
# 647
# well, mujhe nahi nahi nahi ki aap movies ke baare mein nahi lagta hai
# 648
# abhi tho to bhi bhi nahi gaya to ye ise baar ko maja deta hu
# 649
# kya tumhe lagta hai ki is actors ka movie kya hain?
# 650
# is uski best movie ke baare mein kya kya kya kya tumhe lagta hai
# 651
# ye tho really cool hi hota ki ye ek tarah movie kee kaarravaee ke lie achchha kee aavashyakata bana rahe hai.
# 652
# main mujhe bhi aur aur aur us bete mein kuch paise nahi chahiye
# 653
# mujhe mera excited hai ki ye us bachche tha because wo to aisa kar raha tha
# 654
# han
# 655
# aap aap ka matalab hai kya kya kya kya kya kya ? kya kya kya ?
# 656
# ye sach hai, wo kuch pasand nahi hota ki wo ek family ko pasand kar raha hai. mujhe lagta hai ki wo ek baar ko pasand kar raha hai.
# 657
# mujhe lagta hai wo wo yaad nahi tha
# 658
# but aap nahi nahi sakta ki agar agar aap lagta hai agar tum ise baar nahi sakta ho?
# 659
# mein tho kaha ki jahan wo direct kiya hai
# 660
# hello tum ho
# 661
# aap tho movie nahi nahi
# 662
# main bhi tho bahut low hein
# 663
# alright. interesting sound hai
# 664
# haan, ek mysterious creature ke lie right? aur wo ek baar ko liya jaata hai aur wo ek baar ko liya jaata hai aur wo ek baar ko liya
# 665
# ye
# 666
# movie ka kya kya hai?
# 667
# ye to nahi nahi lekin main suna hoon ki main suna hoon ki tum ise batana kar sakte hu
# 668
# nahi bhi kuch bahut achha hein
# 669
# aur ve sach ke liye bahut achchha hai, jo ek bachche family ke liye
# 670
# frank ke liye tho bhi bhi nahi gaya ki uska parents ko use karne ko relate kar raha tha lekin uska beta ko ko karne ko relate kar raha tha
# 671
# ok good
# 672
# kya ka kuch pasand hai
# 673
# hoe tumhe lagta hai ki is movie ko kya pata ho agar mujhe pata ho ki mujhe dekh sakte hu mujhe nahi pata hoon
# 674
# kya is movie ke baare mein kya kya kya tumhe khayal ho kya
# 675
# haan, ye interesting hai jab us ek sister ko shaamil kar deta hai
# 676
# movie ka movies ko pasand karte ho?
# 677
# khair ve ek samay ke liye look kar raha the, aur wo apne dreams ke liye hone ke liye criticize kar raha tha aur wo apne dreams ke liye hone ke liye kar raha hai aur wo ek dreams ke liye hone ke liye
# 678
# main bhi ke toes mein nahi gaya
# 679
# the shape ke liye tho us naav mein se samooh tha
# 680
# mujhe yaad hai ki ye ek type ke tarah hein
# 681
# mujhe bhi ye movie ke baare mein kuch bhi movie ke baare mein kuch lagta hai ki ye movie ko bhi bhi nahi hai. main lagta hai ki ye ek baar ko bhi pasand hai
# 682
# nope, bhee, tho ek great actor hai jo pramukh character play kiya
# 683
# haan, tho us movies ko kuch reekailibret pasand nahi kar sakti
# 684
# but maleficent ne ek timing no-fiction movie hai
# 685
# hello
# 686
# mujhe bhi bhi pasand hai
# 687
# thank
# 688
# wo kya or ratai ko pasand ho?
# 689
# mujhe bhi pasand tha ki usne 1940 mein start kar deta hu :)
# 690
# aur michael tho tho bahut perform kiya
# 691
# oh christian interesting hai. great hai great ki kya ?
# 692
# mujhe bhi lagta hai ki ye movie ke baare mein bahut accha hai. but mujhe movie ki tarah pasand hai.
# 693
# haan, ye tho great ho gaya agar agar wo apni sister ko use feel kar raha tha agar wo ek sister ko leke ki aisa kar raha hai.
# 694
# wo tho yeh lagta hai ki ye ek baar ko pasand karta hai ki wo ek friend ke liye ek philm ke liye ki movie ke liye ek philm ke liye kaam kiya hai
# 695
# mein aur nahi nahi hoon ki mujhe lagtha hai ki ye movie ko pasand kar raha hai. mujhe lagata hai ki ye ek pasand hai.
# 696
# voh tho jinda ko diya tha
# 697
# kuch bhi
# 698
# main bhi sehmat hoon
# 699
# yah mujhe pata hoon ki jab us life ko kam kee naitik kholane ko shaamil chahiye
# 700
# steve tho ek bada bada find hein, jo mein ek character play kiya hai
# 701
# hello, kya tumne movie ke baare mein kya dekha ho?
# 702
# wo tho funny hai
# 703
# haan, voh bahut good hai.
# 704
# thank
# 705
# kya bhi bhi bhi pasand ho?
# 706
# hey kya kaise hain?
# 707
# mujhe tho bahut pasand hein, jo us sari group ko pasand kiya gaya ki wo ek baar ko pasand karta hai
# 708
# thank
# 709
# haan, voh bahut hai ki ye movie ko bahut interesting hai. aur voh ek baar ko pasand kar raha hai.
# 710
# ye bhi abhi nahi nahi
# 711
# acha kya koi monsters hanks hai
# 712
# kya ye movie ke liye suitable hai
# 713
# main movie ka role play kiya hai
# 714
# lol! ab tho ek time se find kar sakte hu
# 715
# amazing ka billionaire hai
# 716
# oops haan, wo ek action scene ke liye try kar raha the, wo ek trying ke liye
# 717
# aap tho lagta hai ki is movie ko kuch baat nahi kar sakta hu ki ye lagta hai ki ye bhi aisa lagata hai ki ye bhi aisa lagata hai ki ye bhi aisa lagata hai ki ye bhi aisa lagata hai ki ye bhi aisa baar chahiye
# 718
# mujhe tho us scenes ke baare mein bhool gaya hoon ki mujhe bhi bhi pasand karta hu
# 719
# kya wo aur aur aur aur aur aur aur aur aur slip ko work kiya
# 720
# kya tho sach hai, billy goodman ek tarah hai.
# 721
# dono ek romanchkari bahut kaam kiya tha jo ek ek sister se
# 722
# wo ache nahi kar raha tha
# 723
# ye ye interesting sound karta hai ki wo ek film ke baare mein kya kaha
# 724
# han ye bhi bhi kuch pasand hai
# 725
# han
# 726
# tho wo is story ko pasand karta hai ki wo decide karne ke liye kaam kiya tha ki voh first baar ko chahata hai.
# 727
# main agree karta hu.
# 728
# movie
# 729
# ya kabhi ko yaad nahi kar sakta ki uski friend ko
# 730
# mujhe matlab hai is movie ko kuch bhi bhi hein aur voh ek friend ke liye kaam kiya hai
# 731
# kya tumhe lagata hai ki ye ek sad hai ki movie ke liye kya hein?
# 732
# mujhe agree, mujhe laga ki movie tha
# 733
# mujhe lagta hai ki aap nahi ho sakta ki ab kabhi kabhi nahi karate hoon. mujhe nahi nahi sakta ki ye kabhi aisa nahi karate hoon.
# 734
# mujhe pta hai ki main apne friends ko nahi nahi gaya aur wo ek baar ko nahi kar deta hai aur wo ek baar ko nahi kar deta hai
# 735
# voh lucious hit ko ko gir gaya aur voh galileo ko kaarravaee ko aathe pade
# 736
# mujhe tho movies ka fan hai, mujhe movie ke baare mein kuch hissa nahi nahi hoon. mujhe movie ke baare mein kya nahi hai.
# 737
# kuch movie ke liye kuch movies nahi nahi
# 738
# tumhe lagta hai ki kya is scene ka kya part hai
# 739
# hi! ab ke baare mein baat kar raha hu ki aap is movie ko dekha ho?
# 740
# haan, ye bhi ko ko play kiya jo ek role ka role kaam kiya hein
# 741
# aap kya ho
# 742
# mujhe nahi nahi hota ki usne wo kuch nahi nahi hota ki voh use nahi nahi kar sakta
# 743
# to, mujhe lagta hai ki ham almighty ko release karna chahiye
# 744
# awesome cast.
# 745
# wo kya or ratai ko pasand ho?
# 746
# mujhe really pasand hein jab voh apne sister ko kaha ki jab aap ko kaha ho gaya ki tumhe ek friend ko badguys
# 747
# wo ek purist tha profession hopps ka q ye.
# 748
# cool. is movie ke liye ek true story thi
# 749
# mujhe bhi 3d rated hui
# 750
# kya aap pata hai ki is movie ke baare mein kya hai?
# 751
# kya aap dekha hai?
# 752
# kya tumhe lagata hai ki is genre ko bhi sochate ho?
# 753
# mujhe tho is movie ko end nahi nahi
# 754
# basically mein tho tho ko ko nahi kar deta hai aur wo ek sister ko liya gaya hai aur wo use conquer kiya
# 755
# mujhe lagta hai ki ve baar ko release karna chahiye
# 756
# ah mujhe great, ek story ki story ki aadhaarit he.
# 757
# mujhe bhi movie ke baare mein dekha hai
# 758
# han
# 759
# ye tho kuch pasand hai
# 760
# sorry main bhi main movies ke baare mein bhi
# 761
# hello!
# 762
# mujhe bhi nahi nahi ki is kids ko bhi bhi bhi bhi bhi bhi maza rahe kar raha hoon
# 763
# mujhe movie pasand hai ki ye ek baare mein kya kya suna ho?
# 764
# acha reviews tho tho mera tomatoes se pasand nahi gaya
# 765
# kuch bhi
# 766
# :) haan wo tho honest nahi gaya
# 767
# haan, voh lagta hai ki wo ek sangeet kee kaarravaee ke lie lagaaya ho gaya
# 768
# aur tumhara favorite part kya hai
# 769
# mujhe bhi bhi bhi nahi nahi ki is life ko kuch nahi nahi kar sakta ki wo use baar ko nahi kar raha ho sakta hai ki wo ek baar ko nahi kar raha
# 770
# mujhe bhi movies ke baare mein suna hai but mujhe suna hai ki mujhe sunni ke baare mein bolo?
# 771
# is tho tho bahut hi hai
# 772
# tom hanks tho ek ache actor hai aur wo ek baar bhi hoga
# 773
# ye bhi kuch bhi bhi hein
# 774
# 2005
# 775
# abhi tho to bhi bhi nahi gaya to ye ise baar ko maja deta hu
# 776
# mujhe bhi lagta hai ki mujhe hamesha adult nahi sakta lekin mujhe kabhi pasand nahi kar sakta hu
# 777
# mujhe lagta hai ki cast hai
# 778
# wo tho ek role ke liye hone ke liye try kiya tha but wo unsucessful hai
# 779
# mujhe bhi agree karna kar sakti hoon
# 780
# ye definitely bhi hai mera parents ko bahut baar bhi feel raha hai aur wo ek baar ke liye ek movie ke liye
# 781
# main main kuch worth hai ya ajj posrwar ya naatak.
# 782
# ek ek fox ka find kiya jo voh ek friend ke liye kaam kiya hai
# 783
# mujhe tho us movie ke baare mein kya jo pasand karte hu. kya kya ?
# 784
# kya is movie ke baare mein kya kya nahi kar sakte hai?
# 785
# ye ek actress aur liye
# 786
# mujhe bhi nahi nahi
# 787
# robert downey jr tho jo bruce ko bruce ko bruce ko bruce ko bruce ko bruce ko bruce ko bruce ko bruce ko bruce ko bruce ko band kiya aur bruce ko arrest kiya aur bruce ko source kare ko kare
# 788
# bhi
# 789
# mujhe bhi agree karna kar sakti hoon
# 790
# gal paas pasand hai ya
# 791
# koi problem nahi hai
# 792
# hi
# 793
# mujhe lagta hai ki is page ke nick tharaf ke baare mein kya kahte ho?
# 794
# bas voh kuch log ko pasand kar raha tha aur wo ek purpose ko pasand kar sakte ho?
# 795
# thank
# 796
# aap ke paas kya kya ho?
# 797
# main bhi ke memory mein nahi jata hu
# 798
# interesting. kya ye kid bhi hai
# 799
# haan rotten tomato 84% aur average: 6.8/10
# 800
# ye streep ka jatkane prasanshak nahi hai
# 801
# wo tho yeh lagta hai ki ye ek baar ko pasand karta hai ki wo ek friend ke liye ek philm ke liye ki movie ke liye ek philm ke liye kaam kiya hai
# 802
# mujhe bhi bhi bhi bhi pasand nahi hota aur mujhe bhi aisa nahi kar sakta hu mujhe bhi aisa nahi kar sakta
# 803
# voh tho kuch krke monolouges tha
# 804
# sabhi ache hai
# 805
# cool ki is baare mein kya
# 806
# kya maantha hoon aur main keira knightly kee pasand nahi karta
# 807
# kya tho tho ek character ke baare mein hai
# 808
# kya mujhe nahi nahi
# 809
# mujhe bhi maleficent ko nahi diya
# 810
# han. voh tho ek time ko pasand karta hai, kya wo ek sister ko aavashyakata kar rahe tha
# 811
# mujhe tho us dream ko bahut kiya, jaise pasand karta hai ki wo ek dreams kee prem kholane ko pasand karta hu.
# 812
# conversation tho actually main check karna gaya
# 813
# bahut bhi bhi!
# 814
# basically tho ek classic hai jo ye ek klaasik movie hai aur ye lagta hai ki ye baar
# 815
# ye sach hai
# 816
# mujhe agree, is scenes ko pasand hai, jo ek deutsches kurl story ke lie janak philm kee aavashyakata kee aavashyakata kee aavashyakata kee aavashyakata kee aavashyakata kee aavashyakata kee aavashyakata se aavashyakata hein
# 817
# hello, kaise ho aap?
# 818
# bahut good sound karta hai ki kaise nahi kar raha ho ki aap ko baar ko nahi chaahate hain, kya aap ko information kar rahe ho, kya aap ko information kar rahe ho, kya kya apne paas ko information kar sakte ho?
# 819
# ye bhi toys ka drama action hai
# 820
# mujhe tho kuch conversation ke baare mein bataane karne ke liye
# 821
# nahi
# 822
# nahin, mujhe nahi dekhi. kya ye ache hai?
# 823
# sweet tho wo bahut ache feel kar raha tha ki voh kuch baar ko feel kar raha tha
# 824
# kya tumhe pata hai jab wo sunni tha
# 825
# mujhe lagta hai ki aapako kuchh pasand karate hai, agar tum ise ootakon kee kaarravaee kee aavashyakata thee. aap lagta hai
# 826
# humanity ka kuch samay ke liye bahut nahin gaya
# 827
# wow ye lagta hai
# 828
# us tho kuch drying se diya
# 829
# oh, ye ek good movie hai jo movie ki movie ki movie
# 830
# well, ye bahut good sound kar raha tha ki is scene ko batman ke liye
# 831
# mujhe tho ek game ka tarah pasand hai jo ye ek day!
# 832
# mujhe believe karta hai ki wo avinata pado,
# 833
# ye definitely mera memory ko ise gambheer likhna chahiye
# 834
# ye tho sach hai, lekin ye yahoodiyon kee kaarravaee kee tulana kee aavashyakata thee. but ye rulane rulane wali hein
# 835
# mujhe tho really yaad nahi tha ki ye bhi.
# 836
# mujhe reviews mujeh accha nahi karta ho? kya kya is movie ko enjoy karoge
# 837
# q
# 838
# mujhe tho movies ke baare mein pasand hai, lekin ye bhi nahi nahi sakta ki agar mujhe nahi nahi nahi to agar wo bhi nahi nahi sakta
# 839
# tho tho acha hai, mujhe nahi hein, mujhe nahi nahi hu mujhe lagta hai ki ye ek baar mein nahi aaya
# 840
# nahi to sure
# 841
# ve ek drephas kee 2d kee adhik pasand karata hu
# 842
# acha tho bhi kaise kiya ki usne har dreams ko kaam kiya hai.
# 843
# wo mool roop se gais taink ko upayog kiya tha
# 844
# oh mujhe bhi bhi bhi bhi bhi uska roop ke saath tho bahut diya tha jo to henry vihaar minute ko memory mein
# 845
# kevin tho us baar ko nahi hein, mujhe lagta hai ki wo ek din ke baare mein hai, lekin ye ek character ke baare mein hai.
# 846
# ya kabhi ko yaad nahi kar sakta ki uski friend ko
# 847
# han ye war scenes ke baare mein ek gambheer probation kee jaroorat jaata hai aur wo apne sister ko apane sister ko dhoondhana hai aur wo apne sister ko apane sister ko lekar aur prashikshit kar raha hai
# 848
# toy story ek computer animated movie ke liye ek philm ke lie ek philm kee aavashyakata kee aavashyakata ke lie realised ho gaya hai
# 849
# acha reviews tho tho mera tomatoes se pasand nahi gaya
# 850
# so good
# 851
# ye ok
# 852
# wo tho uska role ko find kiya
# 853
# haan, voh apne alick sea ko travels kar deta tha aur wo apne dreams ko work kar rahe the, jab wo usse decide karne ke liye way ke liye cheat kar raha tha
# 854
# mujhe bhi, classic ek ek favorite hai
# 855
# mujhe bhi bhi bhi lagta hai ki ye ek baar ko dekha hai
# 856
# kya ye ek crystam ka bakestaar kee citizen acting, jo ek gudamain-hil ka liya
# 857
# voh uski robots ko
# 858
# lakin voh tho to to aur true ko maar deta hai
# 859
# han
# 860
# oh mujhe bhi maleficent ko pasand nahi karta hu
# 861
# mujhe apne know, sarahana hain! lol
# 862
# ye tho nice ho gaya
# 863
# hello!
# 864
# kya ye ne ko star kiya
# 865
# kya is movie ke baare mein kya kya kya tumhe khayal ho kya
# 866
# movie tho ek pej kalpana kee lie thee. jo lagata hai ki ye baar bhi nahi rahe ho?
# 867
# ye bhi
# 868
# wonder woman ka maro aur uska cohen ko ek weasel ka pasand tha
# 869
# mujhe matlab nahi hai
# 870
# tho tho wo uske liye ko ko find kiya
# 871
# well, is film ko nahi nahi tha
# 872
# kya emma stone aur ryan gosling ko acha nahi hein
# 873
# conversation ke liye bahut bada diya tha tumhe din great day!
# 874
# don don daisy ka role play kiya tha?
# 875
# mujhe bhi pasand hai ki us har bachche ko enjoy kiya
# 876
# haan, tho dream ko ek world mein find kiya
# 877
# kya koi koi famous actors aur koi award hain?
# 878
# ek kab jab wo ek sister ke baare mein kya aur aap ko bhi chahiye
# 879
# aap tho kuch bada pasand ho gaya ki tom stromberg jr mein pasand ho sakti hai
# 880
# voh tho neo-noir ko kiya, aur uska technology ko dekhayi gaya aur wo ek dreams kee town" ke lie responsible ke lie responsible ke lie responsible ke lie responsible mein shaamil churaane ke lie responsible ke lie responsible ke saath hoga?
# 881
# oh aur wo true hein.. ek true story thi
# 882
# main to doing appealing tha for
# 883
# kya tho us paragraph ko bataman eventually?
# 884
# jab tho tho supernatural hanks kee thrill tha?
# 885
# wo tho ek bolke praise karne ke lie thank usne uska girlfriend ko le diya
# 886
# main agree karta hu.
# 887
# mujhe bhi pata hai ki ye pay nahi kar sakta hu mujhe lagta hai ki mujhe baar dekhna dekhna chaahate hu
# 888
# kya yar.. ki us done
# 889
# aap tho tho wo kaise kiya tha
# 890
# kya tumne is movie ko dekha
# 891
# main bhi nahi nahi ki ye ek great movie nahi nahi sakta
# 892
# aur ve apni samay se find kiya
# 893
# aur haan, tho tho tho us family ko hein, jab voh usse pasand tha jab jab wo aisa nahi kar raha tha jab wo use pasand hai.
# 894
# jab tho ye ek family ke liye bahut lagta hai ki ye ek baar ko lagta hai ki wo first part ke liye bhi bhi lagta hai
# 895
# oh haan. mujhe is family ko ko pasand karega jo mein apne dreams ko chahiye
# 896
# mujhe lagta hai ki mujhe dekh sakta hu but ye nahi nahi sakta
# 897
# nahin, mujhe nahi dekhi. kya ye ache hai?
# 898
# mujhe bas tho bhi ko ko hone ko nahi hota aur voh apne bad ko hone ke liye hone ke liye way ko nahi kar sakta
# 899
# ye tho sach hai, mujhe lagta hai ki ye bhi ke baare mein kuch pata ho gaya ki aap ko nahi kar sakte ho
# 900
# wo tho aisa pasand karta hu
# 901
# vegas billy tho crystam mein ek weasel ka hai. kya kya ek question hein
# 902
# kya aap marvel scenes ho?
# 903
# the shape ka water ek role movie hai
# 904
# mujhe is movie ke baare mein nahi suna
# 905
# ye ek actress aur liye
# 906
# main tho 15 ke baare mein bhool gaya ki ye ise baar ke baare mein kya kar sakte hu
# 907
# badiya. kya tumhe actor movies movies hai
# 908
# movie tho abhi bhi bhi bhi bhi bhi bhi
# 909
# aap ise ise svayan chahiye
# 910
# ye bhi ke liye ke liye ke baare mein kuch nahi kar raha hu kya to ab tho kuch baar ke liye
# 911
# jim carrey ko nahi hein, aur uska girlfriend ko ko database ko relate kar raha the, aur wo ek sister ko jaatee hai aur wo ek sister ko boarding karne ke liye bruce ke liye bruce ke liye bruce ko kar deta hai
# 912
# kuch movie ke liye kuch movies nahi nahi
# 913
# acha yar..
# 914
# kya
# 915
# is uski best movie ke baare mein kya kya kya kya tumhe lagta hai
# 916
# ohh haan
# 917
# koi bhi
# 918
# bahut bhi but ye ye dekha hai ki ye ye pasand hai ki kya kya ?
# 919
# haan, is reviews tho bahut bahut diya
# 920
# the iron lilly (born dhanyawad
# 921
# hi good ho
# 922
# hello, movie ko accha kiya
# 923
# haan, mujhe lagta hai new school ya voh mar gaya
# 924
# mujhe bhi pasand hai but ye ek baar ko pasand karta hu
# 925
# kya
# 926
# to, mujhe lagta hai ki ham almighty ko release karna chahiye
# 927
# kya tho kuch hi tha
# 928
# kya tumhe pata hai ki agar ye bahut pasand kar raha ho? ye lagta hai ki wo pasand hai
# 929
# ye setting ka filmed hai
# 930
# us log ko naav ko saphalataapoorvak pretentious prashansa kee gaee else elsa ko kisane chaiye
# 931
# aur bhi tho bahut logical laga jab wo ek paartee hai
# 932
# mujhe bhi nahi nahi ki mujhe lagta hai ki wo aisa nahi nahi sakta
# 933
# kya tum inception ho
# 934
# mujhe bhi tho wo is movie mein bahut accha hein
# 935
# mujhe ne ko ko ko se chahiye
# 936
# dono ka kam se
# 937
# ye tho human ho gaya tha
# 938
# hi
# 939
# haan, ye ek part ke baare mein hai jo ek character ke baare mein hai jo mein ke baare mein hai jo mein ke baare mein hai
# 940
# han ye kya
# 941
# oh, ye bahut funny hai. mujhe lagata hai ki ye ek baar ke liye philm hai.
# 942
# hi
# 943
# main kuch pata hai ki wo mike ko kaha ki wo wo adult nahi kar sakta ki wo wo aisa nahi kar sakta tha aur wo use baar ko nahi nahi kar sakta
# 944
# par uski favorite hi
# 945
# mujhe comedies pasand hai
# 946
# haan, aap tho is movie ko end ki aap ko pasand ho gaya
# 947
# han mujhe lagta hai ki ye ek turing ka prem kahaanee ko pasand kar raha tha
# 948
# acha movie ke liye bahut funny hein
# 949
# kya main characters kaun hai?
# 950
# main bhi agree kar sakta hu
# 951
# ye interesting lagata hai ki kya is movie ko dekha
# 952
# tumhe lagta hai ki ye movie ka character ka character ka character ka movie hein
# 953
# tumhe lagta hai ki kya is scene ka kya part hai
# 954
# kya tho kuch hi tha
# 955
# tho ek dicaprio ko thriller hai, lekin voh ek ootakon kee tarah nahi gaya tha jab wo ek baar ko rakha hai.
# 956
# agar mujhe uski bhi bhi pasand hein, yeh tho ab ko bhi bhi nahi gaya
# 957
# ye bhi bura nahi hai kya aap lagta hai ki ham kids ke liye thank you, aap ko baar ko nahi kar rahe
# 958
# han
# 959
# ohh yeah!
# 960
# haan, rotten tomatoes par ek 79% review par mila. but voh ek uchch ank praapt karega.

# %%
fout.close()

# %%
import nltk

# Read reference and hypothesis files
with open('reference1.txt', 'r') as ref_file:
    ref_sent = ref_file.readlines()
with open('hyp1.txt', 'r') as hypo_file:
    hypo_sent = hypo_file.readlines()

# Tokenize sentences
ref_tokens = [[nltk.tokenize.word_tokenize(sent.lower()) for sent in ref_sent]]
hypo_tokens = [[nltk.tokenize.word_tokenize(sent.lower()) for sent in hypo_sent]]

# Calculate BLEU score
bleu_score = nltk.translate.bleu_score.corpus_bleu(ref_tokens, hypo_tokens)

print("BLEU Score:", bleu_score)
# Out:
# BLEU Score: 8.89

# %%
import nltk
nltk.download('words')  
nltk.download('indian') 
english_words = set(nltk.corpus.words.words())  
hindi_words = set(nltk.corpus.indian.words('hindi.pos'))  
words=0
filename = 'predictions_deromanized.txt'  
with open(filename, 'r', encoding='utf-8') as file:
    text = file.read()    
word_list = text.split() 
words=words+len(word_list)
english_word_set = set()
english_word=0
hindi_word_set = set()
hindi_word=0
for word in word_list:
    if word.lower() in english_words:  
        english_word_set.add(word.lower())
        #print(word)
        english_word+=1
    elif all('\u0900' <= c <= '\u097F' for c in word):  
       hindi_word_set.add(word)      
       hindi_word+=1
count=0
for i, j in zip(word_list, word_list[1: ]):
    if i in hindi_word_set and  j in english_word_set:
      count+=1
    elif i in english_word_set and j in hindi_word_set:
      count+=1        
cmi=100*((words-(words-english_word-hindi_word)-max(hindi_word,english_word))/(words-(words-english_word-hindi_word)))
print("code mixing index :",cmi)
mi=(1-((english_word/words)**2+(hindi_word/words)**2))/((english_word/words)**2+(hindi_word/words)**2)
print("M-index:" ,mi)
ii=count/(words-1)
print("I-index:",ii)
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# [nltk_data] Downloading package indian to /root/nltk_data...
# [nltk_data]   Unzipping corpora/indian.zip.
# code mixing index : 12.070211667527103
# M-index: 0.5712703596269515
# I-index: 0.4943598342868416
